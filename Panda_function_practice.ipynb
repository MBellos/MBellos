# %% [markdown]
# <a href="https://colab.research.google.com/github/MBellos/MBellos/blob/main/Panda_function_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Task4a_data.csv')

# %%
df.head()
# Out:
#          Day Pay Type  Tickets  Gift Shop  Snack Stand  Pictures
# 0     Monday     Cash      592        103          243        68
# 1    Tuesday     Cash      390         78          306        56
# 2  Wednesday     Cash      389        107          280        71
# 3   Thursday     Cash      370         98          229        53
# 4     Friday     Cash      628        112          354        49

# %%
df.tail()
# Out:
#           Day Pay Type  Tickets  Gift Shop  Snack Stand  Pictures
# 51  Wednesday     Card      705        260          129       120
# 52   Thursday     Card      729        138          137       204
# 53     Friday     Card      857        137          177       236
# 54   Saturday     Card      471        235          218       291
# 55     Sunday     Card      684        228          228       123

# %%
df.sample(5)
# Out:
#         Day Pay Type  Tickets  Gift Shop  Snack Stand  Pictures
# 53   Friday     Card      857        137          177       236
# 8   Tuesday     Cash      580        128          351        46
# 42   Monday     Card      606        135          127       217
# 14   Monday     Cash      404         72          190        54
# 15  Tuesday     Cash      319        121          233        48

# %%
df.sample(frac=0.1)
# Out:
#           Day Pay Type  Tickets  Gift Shop  Snack Stand  Pictures
# 52   Thursday     Card      729        138          137       204
# 23  Wednesday     Cash      470        140          194        30
# 20     Sunday     Cash      665        111          260        71
# 6      Sunday     Cash      367         88          262        64
# 33   Saturday     Card      648        251          166       201
# 42     Monday     Card      606        135          127       217

# %%
print(df.columns)
# Out:
# Index(['Day', 'Pay Type', 'Tickets', 'Gift Shop', 'Snack Stand', 'Pictures'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          56 non-null     object
#  1   Pay Type     56 non-null     object
#  2   Tickets      56 non-null     int64
#  3   Gift Shop    56 non-null     int64
#  4   Snack Stand  56 non-null     int64
#  5   Pictures     56 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.8+ KB
# None

# %%
print(df.describe())
# Out:
#           Tickets  Gift Shop  Snack Stand    Pictures
# count   56.000000   56.00000    56.000000   56.000000
# mean   579.196429  154.75000   232.178571  139.785714
# std    187.567241   56.49111    64.943082   92.907718
# min    296.000000   71.00000   127.000000   30.000000
# 25%    452.500000  111.00000   181.500000   54.750000
# 50%    557.000000  136.00000   231.000000   99.500000
# 75%    682.500000  207.00000   267.500000  218.250000
# max    999.000000  260.00000   357.000000  319.000000

# %%
print(df[['Snack Stand']].describe())
# Out:
#        Snack Stand
# count    56.000000
# mean    232.178571
# std      64.943082
# min     127.000000
# 25%     181.500000
# 50%     231.000000
# 75%     267.500000
# max     357.000000

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0e566b70f572> in <cell line: 0>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
print(df[['Pay Type', 'Pictures', 'Tickets']])
# Out:
#    Pay Type  Pictures  Tickets
# 0      Cash        68      592
# 1      Cash        56      390
# 2      Cash        71      389
# 3      Cash        53      370
# 4      Cash        49      628
# 5      Cash        50      432
# 6      Cash        64      367
# 7      Cash        44      296
# 8      Cash        46      580
# 9      Cash        45      335
# 10     Cash        42      455
# 11     Cash        44      311
# 12     Cash        64      356
# 13     Cash        44      522
# 14     Cash        54      404
# 15     Cash        48      319
# 16     Cash        72      507
# 17     Cash        79      615
# 18     Cash        55      602
# 19     Cash        66      666
# 20     Cash        71      665
# 21     Cash        75      373
# 22     Cash        56      503
# 23     Cash        30      470
# 24     Cash        51      486
# 25     Cash        59      571
# 26     Cash        72      314
# 27     Cash        30      456
# 28     Card       272      888
# ...

# %%
print (df[[c for c in df.columns if 'P' in c]])
# Out:
#    Pay Type  Pictures
# 0      Cash        68
# 1      Cash        56
# 2      Cash        71
# 3      Cash        53
# 4      Cash        49
# 5      Cash        50
# 6      Cash        64
# 7      Cash        44
# 8      Cash        46
# 9      Cash        45
# 10     Cash        42
# 11     Cash        44
# 12     Cash        64
# 13     Cash        44
# 14     Cash        54
# 15     Cash        48
# 16     Cash        72
# 17     Cash        79
# 18     Cash        55
# 19     Cash        66
# 20     Cash        71
# 21     Cash        75
# 22     Cash        56
# 23     Cash        30
# 24     Cash        51
# 25     Cash        59
# 26     Cash        72
# 27     Cash        30
# 28     Card       272
# 29     Card       224
# 30     Card       284
# 31     Card       215
# 32     Card       198
# 33     Card       201
# 34     Card       259
# 35     Card       177
# 36     Card       186
# 37     Card       183
# 38     Card       171
# 39     Card       177
# ...

# %%
print(df.select_dtypes('int'))
# Out:
#     Tickets  Gift Shop  Snack Stand  Pictures
# 0       592        103          243        68
# 1       390         78          306        56
# 2       389        107          280        71
# 3       370         98          229        53
# 4       628        112          354        49
# 5       432        135          249        50
# 6       367         88          262        64
# 7       296        103          290        44
# 8       580        128          351        46
# 9       335        138          316        45
# 10      455        130          256        42
# 11      311         92          275        44
# 12      356        130          352        64
# 13      522        118          260        44
# 14      404         72          190        54
# 15      319        121          233        48
# 16      507        125          357        72
# 17      615         71          246        79
# 18      602         97          290        55
# ...

# %%
df['Pictures']
# Out:
# 0      68
# 1      56
# 2      71
# 3      53
# 4      49
# 5      50
# 6      64
# 7      44
# 8      46
# 9      45
# 10     42
# 11     44
# 12     64
# 13     44
# 14     54
# 15     48
# 16     72
# 17     79
# 18     55
# 19     66
# 20     71
# 21     75
# 22     56
# 23     30
# 24     51
# 25     59
# 26     72
# 27     30
# 28    272
# 29    224
# 30    284
# 31    215
# 32    198
# 33    201
# 34    259
# 35    177
# 36    186
# 37    183
# 38    171
# 39    177
# 40    256
# 41    177
# 42    217
# 43    194
# 44    288
# 45    319
# 46    222
# 47    264
# 48    286
# 49    302
# 50    224
# 51    120
# 52    204
# 53    236
# 54    291
# 55    123
# Name: Pictures, dtype: int64

# %%
df[['Pictures']]
# Out:
#     Pictures
# 0         68
# 1         56
# 2         71
# 3         53
# 4         49
# 5         50
# 6         64
# 7         44
# 8         46
# 9         45
# 10        42
# 11        44
# 12        64
# 13        44
# 14        54
# 15        48
# 16        72
# 17        79
# 18        55
# 19        66
# 20        71
# 21        75
# 22        56
# 23        30
# 24        51
# 25        59
# 26        72
# 27        30
# 28       272
# 29       224
# 30       284
# 31       215
# 32       198
# 33       201
# 34       259
# 35       177
# 36       186
# 37       183
# 38       171
# 39       177
# 40       256
# 41       177
# 42       217
# 43       194
# 44       288
# 45       319
# 46       222
# 47       264
# 48       286
# 49       302
# 50       224
# 51       120
# 52       204
# 53       236
# 54       291
# 55       123

# %%
print(df.loc[:3, :2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-4362a2e81be6> in <cell line: 0>()
# ----> 1 print(df.loc[:3, :3])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1375             return self._multi_take(tup)
#    1376
# -> 1377         return self._getitem_tuple_same_dim(tup)
#    1378
#    1379     def _get_label(self, label, axis: AxisInt):
#
# ...

# %%
print(df.loc[(df['Pay Type'] == 'Card')])
# Out:
#           Day Pay Type  Tickets  Gift Shop  Snack Stand  Pictures
# 28     Monday     Card      888        193          162       272
# 29    Tuesday     Card      586        144          204       224
# 30  Wednesday     Card      584        198          187       284
# 31   Thursday     Card      555        183          152       215
# 32     Friday     Card      942        209          236       198
# 33   Saturday     Card      648        251          166       201
# 34     Sunday     Card      551        165          174       259
# 35     Monday     Card      445        192          193       177
# 36    Tuesday     Card      870        239          234       186
# 37  Wednesday     Card      502        257          210       183
# 38   Thursday     Card      682        242          170       171
# 39     Friday     Card      466        170          183       177
# 40   Saturday     Card      534        241          235       256
# ...

# %%
mon_card_sale = (df.loc[(df['Pay Type'] == 'Card') & (df['Day'] == 'Monday')])
print(mon_card_sale.select_dtypes('int').sum())

mon_card_sale.describe()
# Out:
# Tickets        2498
# Gift Shop       727
# Snack Stand     610
# Pictures        968
# dtype: int64

# %%
print(df.query[df('Snack Stand' > 100) amd ('Pay Type == "Card"')])
# Out:
#   File "<ipython-input-91-5bb148db362c>", line 1
#     print(df.query[df('Snack Stand' > 100) amd ('Pay Type == "Card"')])
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(df['Pictures'].min())
# Out:
# 30

# %%
print(df['Pictures'].max())
# Out:
# 319

# %%
print(df['Pictures'].var())
# Out:
# 8631.844155844155

# %%
print(df['Pictures'].sum())
# Out:
# 7828

# %%
print(df[['Tickets', 'Snack Stand', 'Gift Shop', 'Pictures']].agg(['sum', 'min', 'max', 'mean']))
# Out:
#            Tickets   Snack Stand  Gift Shop     Pictures
# sum   32435.000000  13002.000000    8666.00  7828.000000
# min     296.000000    127.000000      71.00    30.000000
# max     999.000000    357.000000     260.00   319.000000
# mean    579.196429    232.178571     154.75   139.785714

# %%
print(df[['Day', 'Pay Type']].value_counts())
# Out:
# Day        Pay Type
# Friday     Card        4
#            Cash        4
# Monday     Card        4
#            Cash        4
# Saturday   Card        4
#            Cash        4
# Sunday     Card        4
#            Cash        4
# Thursday   Card        4
#            Cash        4
# Tuesday    Card        4
#            Cash        4
# Wednesday  Card        4
#            Cash        4
# Name: count, dtype: int64

# %%
print(df.groupby('Day')[['Gift Shop']].agg(['mean', 'max', 'min']))
# Out:
#           Gift Shop
#                mean  max  min
# Day
# Friday      133.875  209   74
# Monday      139.500  207   72
# Saturday    183.375  251  122
# Sunday      157.375  228   88
# Thursday    133.375  242   71
# Tuesday     153.500  239   78
# Wednesday   182.250  260  107
